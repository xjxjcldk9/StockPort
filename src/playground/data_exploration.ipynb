# %%
import pandas as pd 
pd.options.display.max_columns = 999

# %%
df = pd.read_csv('stocks.csv')
df
# Out:
#        年度/季別  營業現金對流動負債比%  營業現金對負債比%  營業現金流對淨利比%  負債佔資產比%  長期資金佔固定資產比%  \
# 0     2023Q3        30.37      13.95      139.78    38.50       144.11
# 1     2023Q2        20.63       8.60       92.04    37.75       147.21
# 2     2023Q1        44.12      19.73      186.15    38.70       147.27
# 3     2022Q4        51.56      24.29      164.55    40.37       149.25
# 4     2022Q3        51.11      21.82      146.88    40.73       159.07
# ...      ...          ...        ...         ...      ...          ...
# 2551  2020Q1        12.78      10.62      169.36    45.25       274.58
# 2552  2019Q4         9.64       8.18       87.52    47.34       262.60
# 2553  2019Q3         5.78       4.78       58.29    48.35       271.32
# 2554  2019Q2         6.02       5.11       89.59    49.66       270.07
# 2555  2019Q1         4.62       3.24       64.90    42.98       304.65
#
#         流動比%    速動比%  應收帳款收現(天)  存貨週轉(天)  營運週轉(天)  單季ROE%  單季ROA%   毛利率%  \
# ...

# %%
df.drop(columns='季收盤價成長率y').isna().mean() < 0.05
# Out:
# 年度/季別           True
# 營業現金對流動負債比%     True
# 營業現金對負債比%       True
# 營業現金流對淨利比%      True
# 負債佔資產比%         True
# 長期資金佔固定資產比%     True
# 流動比%            True
# 速動比%            True
# 應收帳款收現(天)       True
# 存貨週轉(天)         True
# 營運週轉(天)         True
# 單季ROE%          True
# 單季ROA%          True
# 毛利率%            True
# 營業利益率%          True
# 稅前淨利率%          True
# 稅後淨利率%          True
# 單季營業利益季增率%      True
# 近4季營業利益季增率%     True
# 每股盈餘            True
# 每股盈餘季增率         True
# 每股盈餘年增率         True
# 每股淨值            True
# 本益比(倍)         False
# 股價淨值比(倍)       False
# 代碼              True
# 股票名稱            True
# 產業              True
# dtype: bool
